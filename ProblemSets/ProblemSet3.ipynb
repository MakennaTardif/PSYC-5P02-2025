# %% [markdown]
# # PSYC 5P02- Introduction to Programming for Psychology
# ## Fall 2025
#
# ### Problem Set #3
# ### Assigned October 10 - Due October 23
# ### Late Penalty: 5%/day
#
# * To compete this assignment, produce ALL relevant code for each of the questions. You can answer the questions in a Notebook or by creating a .py file.
#
# * ALL CODE MUST BE THOROUGHLY DOCUMENTED! You can use Notebook Markup or comments, but you must be detailed in your explanations of your code. Feel free to provide an explanation for your approach to solving a problem.
#
# * For each question, try to use the most efficient code you can to produce each response, unless otherwise specified.
#
# * All relevant files must be uploaded to a git repository that is shared with me (user: SMEmrich) in order for the assignment to be considered submitted. Please be sure to put all files in a separate folder (e.g., /PS2/ProblemSet2.ipynb)
#
# * Please avoid using ChatGPT, CoPilot or any other AI assistance to complete this assignment. If you do end up using it, please explain in your comment/Markdown notes where you got stuck, describe the code that was produced, and explain how the solution got around what you coudn't figure out
#
#
# ### Rubric:
# * Accuracy & Efficiency: 50%
# * Explaination and documentation: 50%

# %% [markdown]
# 1)	Using PsychoPy, create a visual search experiment. The goal should be for subjects to find a target letter (T) among a group of distractor letters (Ls) (see included images). The target should only be present on 50% of trials.
#
# Additional functionality to incorporate (add as many of these as possible):
#
# - Participants should respond to the presence or absence of the target using a keyboard response, and the program should measure RTs and accuracy.
# - Include a key that will escape the program
# - There should be three conditions that vary the total set size (e.g., 8, 12, 14).
# - The total number of images shown is constant (i.e., target absent trials include an extra distractor)
# - Distractors should also have different rotations (0, 90, 180, 270).
# - Take as input the number of trials per condition and participant number
# - Save data to file
# - Provide instructions and practice trials
# - The search display times out if a response isn’t made quickly enough (e..g, < 1.0 seconds)
# - Provide feedback on responses
# - Print to the screen accuracy and average RTs after the experiment is done
#
#
# Bonus:
# Define as much of the above in a class.
#
# ---
#
#
# ![T.png](T.png) ![L.png](L.png)
